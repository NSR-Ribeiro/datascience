# %%
import pandas as pd

url = "dataset/materiais_construcao.csv"
pd.read_csv(url,sep=",")
# Out:
#               id  default  idade sexo  dependentes         escolaridade  \
# 0      768805383        0     45    M            3         ensino medio
# 1      818770008        0     49    F            5             mestrado
# 2      713982108        0     51    M            3             mestrado
# 3      769911858        0     40    F            4         ensino medio
# 4      709106358        0     40    M            3  sem educacao formal
# ...          ...      ...    ...  ...          ...                  ...
# 10122  772366833        0     50    M            2             mestrado
# 10123  710638233        1     41    M            2                   na
# 10124  716506083        1     44    F            1         ensino medio
# 10125  717406983        1     30    M            2             mestrado
# 10126  714337233        1     43    F            2             mestrado
#
#       estado_civil   salario_anual tipo_cartao  meses_de_relacionamento  \
# ...

# %%
comprador = pd.read_csv(url,sep=",")

# %% [markdown]
# # Lendo 5 primeiros dados

# %%
comprador.head() # número acrescentado entre parentese definem quantidades de linhas visualizadas
# Out:
#           id  default  idade sexo  dependentes         escolaridade  \
# 0  768805383        0     45    M            3         ensino medio
# 1  818770008        0     49    F            5             mestrado
# 2  713982108        0     51    M            3             mestrado
# 3  769911858        0     40    F            4         ensino medio
# 4  709106358        0     40    M            3  sem educacao formal
#
#   estado_civil   salario_anual tipo_cartao  meses_de_relacionamento  \
# 0       casado     $60K - $80K        blue                       39
# 1     solteiro  menos que $40K        blue                       44
# 2       casado    $80K - $120K        blue                       36
# 3           na  menos que $40K        blue                       34
# 4       casado     $60K - $80K        blue                       21
#
#    qtd_produtos  iteracoes_12m  meses_inativo_12m limite_credito  \
# 0             5              3                  1      12.691,51
# ...

# %%
comprador.tail(10)
# Out:
#               id  default  idade sexo  dependentes         escolaridade  \
# 10117  712503408        0     57    M            2             mestrado
# 10118  713755458        1     50    M            1                   na
# 10119  716893683        1     55    F            3  sem educacao formal
# 10120  710841183        0     54    M            1         ensino medio
# 10121  713899383        0     56    F            1             mestrado
# 10122  772366833        0     50    M            2             mestrado
# 10123  710638233        1     41    M            2                   na
# 10124  716506083        1     44    F            1         ensino medio
# 10125  717406983        1     30    M            2             mestrado
# 10126  714337233        1     43    F            2             mestrado
#
#       estado_civil   salario_anual tipo_cartao  meses_de_relacionamento  \
# 10117       casado    $80K - $120K        blue                       40
# ...
