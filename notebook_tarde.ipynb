# %%
! pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\ead\desktop\exercício-tarde-avaliação\.venv\lib\site-packages (2.0.31)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\ead\desktop\exercício-tarde-avaliação\.venv\lib\site-packages (from sqlalchemy) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ead\desktop\exercício-tarde-avaliação\.venv\lib\site-packages (from sqlalchemy) (3.0.3)

# %%
! pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\ead\desktop\exercício-tarde-avaliação\.venv\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\ead\desktop\exercício-tarde-avaliação\.venv\lib\site-packages (from pandas) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ead\desktop\exercício-tarde-avaliação\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ead\desktop\exercício-tarde-avaliação\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ead\desktop\exercício-tarde-avaliação\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\ead\desktop\exercício-tarde-avaliação\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd

# %%
# Módulo
from sqlalchemy import  create_engine

# %%
! pip install pymysql
# Out:
# Requirement already satisfied: pymysql in c:\users\ead\desktop\exercício-tarde-avaliação\.venv\lib\site-packages (1.1.1)

# %%
import pymysql
import urllib.parse
# definir as credenciais
user = 'root'
password = urllib.parse.quote_plus('senai@123')
host  = 'localhost'
database = 'projetodiario1'
# criar uma url de conexão
connection_string = f'mysql+pymysql://{user}:{password}@{host}/{database}'
# criar a conexão com o create_engine()
engine = create_engine(connection_string)
# escrever uma consulta SQL
query_alunos = "SELECT * FROM aluno"
# criar o dataframe
df_alunos = pd.read_sql(query_alunos,engine)
# mostrar os cinco primeiros
df_alunos.head()
# Out:
#    id        ra  Nome  tempoestudo  rendafamiliar
# 0   1  12345678  None            0            NaN
# 1   2  12345679  None            0            NaN
# 2   3  12345608  None            0            NaN
# 3   4  12375678  None            0            NaN
# 4   5  12345878  None            0            NaN

# %% [markdown]
# # Quais bibliotecas um ceintista de dados utiliza?

# %% [markdown]
# - Pandas
# - NumPy
# - Fundamentos de IA (Scikit-Learn)

# %% [markdown]
# - Material Didático
# - Pandas e NumPy (Notebook)
# - Scikit-learn (Apostila de Senai)

# %% [markdown]
# Pandas: ciencia de dados
# Skit-Learn: elaboração de modelos de IA
#
# NmPy: matemática
# 05/08/2024

# %% [markdown]
# - Carregar dados (ok)

# %% [markdown]
# - Salvar um datafrane

# %% [markdown]
# csv_filename = 'alunos.csv'
# df_alunos.to_csv('aluno.csv',index=False)

# %%
csv_filename = 'alunos.json'
df_alunos.to_json('aluno.json',index=False)

# %%
csv_filename = 'alunos.xlsx'
df_alunos.to_excel(csv_filename,index=False)

# %% [markdown]
# # Eu salvei o dataframe!

# %% [markdown]
# # Um novo DataFrame

# %%
df_alunos.columns
# Out:
# Index(['id', 'ra', 'Nome', 'tempoestudo', 'rendafamiliar'], dtype='object')

# %%
df_tempo_renda = df_alunos[['tempoestudo','rendafamiliar']]
df_tempo_renda
# Out:
#     tempoestudo  rendafamiliar
# 0             0            NaN
# 1             0            NaN
# 2             0            NaN
# 3             0            NaN
# 4             0            NaN
# ..          ...            ...
# 79           14         3000.0
# 80           22         3600.0
# 81           18         3200.0
# 82           17         3100.0
# 83           15         3300.0
#
# [84 rows x 2 columns]

# %%
print(type(df_tempo_renda))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # Exercício: crie um recurso para mostrar apenas uma coluna. Mostre qual o tipo desse recurso.

# %%
df_tempo_renda = df_alunos[['rendafamiliar']]

print(df_tempo_renda.head())
# Out:
#    rendafamiliar
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
serie_tempo_renda = df_tempo_renda['rendafamiliar']

# %%
type(serie_tempo_renda)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Exercicio

# %% [markdown]
# # Extensão para excel
#
# ! pip install openpyxl

# %%
! pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\ead\desktop\exercício-tarde-avaliação\.venv\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\ead\desktop\exercício-tarde-avaliação\.venv\lib\site-packages (from openpyxl) (1.1.0)

# %% [markdown]
# # Revisando Funções Básicas

# %% [markdown]
# Pandas (funções agragados)

# %% [markdown]
# # O Web scraping, ou "raspagem de dados"
#
# coletar dados

# %%
! pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\users\ead\desktop\exercício-tarde-avaliação\.venv\lib\site-packages (5.2.2)

# %%
url = "https://www.uol.com.br/esporte/futebol/campeonatos/brasileirao/"
tabela_seriea = pd.read_html(url)
tabela_seriea
# Out:
# [                 classificação
#  0               1° BotafogoBOT
#  1               2° FlamengoFLA
#  2              3° FortalezaFOR
#  3              4° PalmeirasPAL
#  4               5° CruzeiroCRU
#  5              6° São PauloSPA
#  6                  7° BahiaBAH
#  7              8° AthleticoCAP
#  8            9° Atlético-MGCAM
#  9   10° Red Bull BragantinoBRG
#  10                11° VascoVAS
#  11             12° CriciúmaCRI
#  12            13° JuventudeJUV
#  13               14° GrêmioGRE
#  14              15° VitóriaVIT
#  15        16° InternacionalINT
#  16           17° FluminenseFLU
#  17          18° CorinthiansCOR
#  18               19° CuiabáCUI
#  19          20° Atlético-GOACG,
#      PG   J   V  E   D  GC  GP  SG   %
#  0   43  21  13  4   4  20  35  15  68
#  1   40  20  12  4   4  20  34  14  67
#  2   39  20  11  6   3  19  26   7  65
#  3   37  21  11  4   6  17  28  11  59
#  4   35  20  11  2   7  22  29   7  58
#  5   35  21  10  5   6  21  29   8  56
#  6   32  21   9  5   7  25  29   4  51
#  7   28  19   8  4   7  20  22   2  49
#  8   28  19   7  7   5  28  28   0  49
#  9   26  19   7  5   7  23  24   1  46
#  10  24  20   7  3  10  31  22  -9  40
#  11  24  19   6  6   7  29  28  -1  42
#  12  22  19   5  7   7  25  21  -4  39
#  13  21  19   6  3  10  22  17  -5  37
#  14  21  21   6  3  12  32  23  -9  33
#  15  21  16   5  6   5  14  14   0  44
#  16  20  20   5  5  10  24  16  -8  33
#  17  20  21   4  8   9  28  19  -9  32
#  18  17  19   4  5  10  25  19  -6  30
#  19  12  21   2  6  13  35  17 -18  19,
#                                         classificação
#  0  {{team._index + 1}}° {{team.equipe['nome-comum...,
#              PG           J           V           E           D           GP  \
#  0  {{team.pg}}  {{team.j}}  {{team.v}}  {{team.e}}  {{team.d}}  {{team.gp}}
#
#              GC           SG            %  \
#  0  {{team.gc}}  {{team.sg}}  {{team.ap}}
#
#                                         Últimos jogos
#  0  {{game.weekDay | uppercase}}, {{game.newDate}}...  ]

# %%
type(tabela_seriea)
# Out:
# list

# %%
url = 'https://www.uol.com.br/esporte/futebol/campeonatos/brasileirao/'
tabelas = pd.read_html(url)

tabela_brasileirao = tabelas[0]


display(tabela_brasileirao)
# Out:
#                  classificação
# 0               1° BotafogoBOT
# 1               2° FlamengoFLA
# 2              3° FortalezaFOR
# 3              4° PalmeirasPAL
# 4               5° CruzeiroCRU
# 5              6° São PauloSPA
# 6                  7° BahiaBAH
# 7              8° AthleticoCAP
# 8            9° Atlético-MGCAM
# 9   10° Red Bull BragantinoBRG
# 10                11° VascoVAS
# 11             12° CriciúmaCRI
# 12            13° JuventudeJUV
# 13               14° GrêmioGRE
# 14              15° VitóriaVIT
# 15        16° InternacionalINT
# 16           17° FluminenseFLU
# 17          18° CorinthiansCOR
# 18               19° CuiabáCUI
# 19          20° Atlético-GOACG

# %%
tabela_brasileirao = tabela_seriea[0]
tabela_brasileirao
# Out:
#                  classificação
# 0               1° BotafogoBOT
# 1               2° FlamengoFLA
# 2              3° FortalezaFOR
# 3              4° PalmeirasPAL
# 4               5° CruzeiroCRU
# 5              6° São PauloSPA
# 6                  7° BahiaBAH
# 7              8° AthleticoCAP
# 8            9° Atlético-MGCAM
# 9   10° Red Bull BragantinoBRG
# 10                11° VascoVAS
# 11             12° CriciúmaCRI
# 12            13° JuventudeJUV
# 13               14° GrêmioGRE
# 14              15° VitóriaVIT
# 15        16° InternacionalINT
# 16           17° FluminenseFLU
# 17          18° CorinthiansCOR
# 18               19° CuiabáCUI
# 19          20° Atlético-GOACG

# %%
tabela_seriea[0].head()
# Out:
#      classificação
# 0   1° BotafogoBOT
# 1   2° FlamengoFLA
# 2  3° FortalezaFOR
# 3  4° PalmeirasPAL
# 4   5° CruzeiroCRU

# %%
url = 'https://www.terra.com.br/esportes/futebol/brasileiro-serie-a/tabela/'
tabelas = pd.read_html(url)

tabela_brasileirao = tabelas[0]


display(tabela_brasileirao)
# Out:
#     Times  Times.1                  Times.2  Times.3   P   J   V  E   D  GP  \
# 0       1      NaN              Botafogo >>   Subiu1  43  21  13  4   4  35
# 1       2      NaN              Flamengo >>  Desceu1  40  20  12  4   4  34
# 2       3      NaN             Fortaleza >>   Subiu1  39  20  11  6   3  26
# 3       4      NaN             Palmeiras >>  Desceu1  37  21  11  4   6  28
# 4       5      NaN              Cruzeiro >>      NaN  35  20  11  2   7  29
# 5       6      NaN            SÃ£o Paulo >>      NaN  35  21  10  5   6  29
# 6       7      NaN                 Bahia >>      NaN  32  21   9  5   7  29
# 7       8      NaN          Athletico-PR >>      NaN  28  19   8  4   7  22
# 8       9      NaN          AtlÃ©tico-MG >>      NaN  28  19   7  7   5  28
# 9      10      NaN            Bragantino >>      NaN  26  19   7  5   7  24
# 10     11      NaN         Vasco da Gama >>      NaN  24  20   7  3  10  22
# 11     12      NaN             CriciÃºma >>      NaN  24  19   6  6   7  28
# 12     13      NaN             Juventude >>      NaN  22  19   5  7   7  21
# 13     14      NaN               GrÃªmio >>   Subiu2  21  19   6  3  10  17
# 14     15      NaN              VitÃ³ria >>   Subiu2  21  21   6  3  12  23
# 15     16      NaN         Internacional >>  Desceu2  21  16   5  6   5  14
# 16     17      NaN            Fluminense >>   Subiu2  20  20   5  5  10  16
# 17     18      NaN           Corinthians >>  Desceu3  20  21   4  8   9  19
# 18     19      NaN               CuiabÃ¡ >>  Desceu1  17  19   4  5  10  19
# 19     20      NaN  AtlÃ©tico Goianiense >>      NaN  12  21   2  6  13  17
#
#     GC  SG   %
# 0   20  15  68
# 1   20  14  66
# 2   19   7  65
# 3   17  11  58
# 4   22   7  58
# 5   21   8  55
# 6   25   4  50
# 7   20   2  49
# 8   28   0  49
# 9   23   1  45
# 10  31  -9  40
# 11  29  -1  42
# 12  25  -4  38
# 13  22  -5  36
# 14  32  -9  33
# 15  14   0  43
# 16  24  -8  33
# 17  28  -9  31
# 18  25  -6  29
# 19  35 -18  19

# %%
url = 'https://www.terra.com.br/esportes/futebol/brasileiro-serie-a/tabela/#google_vignette'
tabelas = pd.read_html(url)

tabela_brasileirao = tabelas[0]


display(tabela_brasileirao)
# Out:
#     Times  Times.1                  Times.2  Times.3   P   J   V  E   D  GP  \
# 0       1      NaN              Botafogo >>   Subiu1  43  21  13  4   4  35
# 1       2      NaN              Flamengo >>  Desceu1  40  20  12  4   4  34
# 2       3      NaN             Fortaleza >>   Subiu1  39  20  11  6   3  26
# 3       4      NaN             Palmeiras >>  Desceu1  37  21  11  4   6  28
# 4       5      NaN              Cruzeiro >>      NaN  35  20  11  2   7  29
# 5       6      NaN            SÃ£o Paulo >>      NaN  35  21  10  5   6  29
# 6       7      NaN                 Bahia >>      NaN  32  21   9  5   7  29
# 7       8      NaN          Athletico-PR >>      NaN  28  19   8  4   7  22
# 8       9      NaN          AtlÃ©tico-MG >>      NaN  28  19   7  7   5  28
# 9      10      NaN            Bragantino >>      NaN  26  19   7  5   7  24
# 10     11      NaN         Vasco da Gama >>      NaN  24  20   7  3  10  22
# 11     12      NaN             CriciÃºma >>      NaN  24  19   6  6   7  28
# 12     13      NaN             Juventude >>      NaN  22  19   5  7   7  21
# 13     14      NaN               GrÃªmio >>   Subiu2  21  19   6  3  10  17
# 14     15      NaN              VitÃ³ria >>   Subiu2  21  21   6  3  12  23
# 15     16      NaN         Internacional >>  Desceu2  21  16   5  6   5  14
# 16     17      NaN            Fluminense >>   Subiu2  20  20   5  5  10  16
# 17     18      NaN           Corinthians >>  Desceu3  20  21   4  8   9  19
# 18     19      NaN               CuiabÃ¡ >>  Desceu1  17  19   4  5  10  19
# 19     20      NaN  AtlÃ©tico Goianiense >>      NaN  12  21   2  6  13  17
#
#     GC  SG   %
# 0   20  15  68
# 1   20  14  66
# 2   19   7  65
# 3   17  11  58
# 4   22   7  58
# 5   21   8  55
# 6   25   4  50
# 7   20   2  49
# 8   28   0  49
# 9   23   1  45
# 10  31  -9  40
# 11  29  -1  42
# 12  25  -4  38
# 13  22  -5  36
# 14  32  -9  33
# 15  14   0  43
# 16  24  -8  33
# 17  28  -9  31
# 18  25  -6  29
# 19  35 -18  19

# %%
tabela_brasileirao.head()
# Out:
#    Times  Times.1       Times.2  Times.3   P   J   V  E  D  GP  GC  SG   %
# 0      1      NaN   Botafogo >>   Subiu1  43  21  13  4  4  35  20  15  68
# 1      2      NaN   Flamengo >>  Desceu1  40  20  12  4  4  34  20  14  66
# 2      3      NaN  Fortaleza >>   Subiu1  39  20  11  6  3  26  19   7  65
# 3      4      NaN  Palmeiras >>  Desceu1  37  21  11  4  6  28  17  11  58
# 4      5      NaN   Cruzeiro >>      NaN  35  20  11  2  7  29  22   7  58

# %%
tabela_brasileirao.tail()
# Out:
#     Times  Times.1                  Times.2  Times.3   P   J  V  E   D  GP  \
# 15     16      NaN         Internacional >>  Desceu2  21  16  5  6   5  14
# 16     17      NaN            Fluminense >>   Subiu2  20  20  5  5  10  16
# 17     18      NaN           Corinthians >>  Desceu3  20  21  4  8   9  19
# 18     19      NaN               CuiabÃ¡ >>  Desceu1  17  19  4  5  10  19
# 19     20      NaN  AtlÃ©tico Goianiense >>      NaN  12  21  2  6  13  17
#
#     GC  SG   %
# 15  14   0  43
# 16  24  -8  33
# 17  28  -9  31
# 18  25  -6  29
# 19  35 -18  19

# %%
tabela_brasileirao.shape
# Out:
# (20, 13)

# %%
tabela_brasileirao.columns
# Out:
# Index(['Times', 'Times.1', 'Times.2', 'Times.3', 'P', 'J', 'V', 'E', 'D', 'GP',
#        'GC', 'SG', '%'],
#       dtype='object')

# %%
tabela_brasileirao['Times.2']
# Out:
# 0                 Botafogo >>
# 1                 Flamengo >>
# 2                Fortaleza >>
# 3                Palmeiras >>
# 4                 Cruzeiro >>
# 5               SÃ£o Paulo >>
# 6                    Bahia >>
# 7             Athletico-PR >>
# 8             AtlÃ©tico-MG >>
# 9               Bragantino >>
# 10           Vasco da Gama >>
# 11               CriciÃºma >>
# 12               Juventude >>
# 13                 GrÃªmio >>
# 14                VitÃ³ria >>
# 15           Internacional >>
# 16              Fluminense >>
# 17             Corinthians >>
# 18                 CuiabÃ¡ >>
# 19    AtlÃ©tico Goianiense >>
# Name: Times.2, dtype: object

# %%
tabela_brasileirao = tabela_brasileirao.drop(columns=['Times','Times.1','Times.3'],inplace=True)

# %%
tabela_brasileirao = tabela_brasileirao.drop(columns=['Times','Times.1','Times.3'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 tabela_brasileirao = tabela_brasileirao.drop(columns=['Times','Times.1','Times.3'])
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %%
tabela_brasileirao

# %%
tabela_brasileirao[['Times.2','V']]
# Out:
#                     Times.2   V
# 0               Botafogo >>  13
# 1               Flamengo >>  12
# 2              Fortaleza >>  11
# 3              Palmeiras >>  11
# 4               Cruzeiro >>  11
# 5             SÃ£o Paulo >>  10
# 6                  Bahia >>   9
# 7           Athletico-PR >>   8
# 8           AtlÃ©tico-MG >>   7
# 9             Bragantino >>   7
# 10         Vasco da Gama >>   7
# 11             CriciÃºma >>   6
# 12             Juventude >>   5
# 13               GrÃªmio >>   6
# 14              VitÃ³ria >>   6
# 15         Internacional >>   5
# 16            Fluminense >>   5
# 17           Corinthians >>   4
# 18               CuiabÃ¡ >>   4
# 19  AtlÃ©tico Goianiense >>   2

# %%
tabela_brasileirao['%'].mean()
# Out:
# np.float64(45.35)

# %%
tabela_brasileirao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Times.2  20 non-null     object
#  1   P        20 non-null     int64
#  2   J        20 non-null     int64
#  3   V        20 non-null     int64
#  4   E        20 non-null     int64
#  5   D        20 non-null     int64
#  6   GP       20 non-null     int64
#  7   GC       20 non-null     int64
#  8   SG       20 non-null     int64
#  9   %        20 non-null     int64
# dtypes: int64(9), object(1)
# memory usage: 1.7+ KB

# %%
tabela_brasileirao.describe()
# Out:
#               P          J          V          E          D         GP  \
# count  20.00000  20.000000  20.000000  20.000000  20.000000  20.000000
# mean   27.25000  19.800000   7.450000   4.900000   7.450000  24.000000
# std     8.57705   1.239694   3.051747   1.552587   2.723678   5.973626
# min    12.00000  16.000000   2.000000   2.000000   3.000000  14.000000
# 25%    21.00000  19.000000   5.000000   4.000000   5.750000  19.000000
# 50%    25.00000  20.000000   7.000000   5.000000   7.000000  23.500000
# 75%    35.00000  21.000000  10.250000   6.000000  10.000000  28.250000
# max    43.00000  21.000000  13.000000   8.000000  13.000000  35.000000
#
#              GC         SG          %
# count  20.00000  20.000000  20.000000
# mean   24.00000   0.000000  45.350000
# std     5.30144   8.687559  13.468384
# min    14.00000 -18.000000  19.000000
# 25%    20.00000  -6.500000  35.250000
# 50%    23.50000   0.000000  44.000000
# 75%    28.00000   7.000000  55.750000
# max    35.00000  15.000000  68.000000

# %% [markdown]
# # - Tabular - tabela da página

# %%
tabela_brasileirao.rename(columns={'Times.2': 'Times'}, inplace=True)

# %%
print(tabela_brasileirao)
# Out:
#                    Times   P   J   V  E   D  GP  GC  SG   %
# 0               Botafogo  43  21  13  4   4  35  20  15  68
# 1               Flamengo  40  20  12  4   4  34  20  14  66
# 2              Fortaleza  39  20  11  6   3  26  19   7  65
# 3              Palmeiras  37  21  11  4   6  28  17  11  58
# 4               Cruzeiro  35  20  11  2   7  29  22   7  58
# 5             SÃ£o Paulo  35  21  10  5   6  29  21   8  55
# 6                  Bahia  32  21   9  5   7  29  25   4  50
# 7           Athletico-PR  28  19   8  4   7  22  20   2  49
# 8           AtlÃ©tico-MG  28  19   7  7   5  28  28   0  49
# 9             Bragantino  26  19   7  5   7  24  23   1  45
# 10         Vasco da Gama  24  20   7  3  10  22  31  -9  40
# 11             CriciÃºma  24  19   6  6   7  28  29  -1  42
# 12             Juventude  22  19   5  7   7  21  25  -4  38
# 13               GrÃªmio  21  19   6  3  10  17  22  -5  36
# 14              VitÃ³ria  21  21   6  3  12  23  32  -9  33
# 15         Internacional  21  16   5  6   5  14  14   0  43
# 16            Fluminense  20  20   5  5  10  16  24  -8  33
# 17           Corinthians  20  21   4  8   9  19  28  -9  31
# 18               CuiabÃ¡  17  19   4  5  10  19  25  -6  29
# 19  AtlÃ©tico Goianiense  12  21   2  6  13  17  35 -18  19

# %% [markdown]
# # Expressão regular
#
# str.replace('>>', regex=False)
# substitui >> por uma string vazia.
# reges=False
# indica que >> é um texto, não uma expressão regular.

# %% [markdown]
# # Usando str.strip
#
# Para remover espaços em branco no início e no fim dos dados da coluna.
#
# str.replace('>>', regex=False)
# reges=False

# %%
tabela_brasileirao['Times'] = tabela_brasileirao['Times'].str.replace('>>', '', regex=False).str.strip()

# %%
print(tabela_brasileirao)
# Out:
#                    Times   P   J   V  E   D  GP  GC  SG   %
# 0               Botafogo  43  21  13  4   4  35  20  15  68
# 1               Flamengo  40  20  12  4   4  34  20  14  66
# 2              Fortaleza  39  20  11  6   3  26  19   7  65
# 3              Palmeiras  37  21  11  4   6  28  17  11  58
# 4               Cruzeiro  35  20  11  2   7  29  22   7  58
# 5             SÃ£o Paulo  35  21  10  5   6  29  21   8  55
# 6                  Bahia  32  21   9  5   7  29  25   4  50
# 7           Athletico-PR  28  19   8  4   7  22  20   2  49
# 8           AtlÃ©tico-MG  28  19   7  7   5  28  28   0  49
# 9             Bragantino  26  19   7  5   7  24  23   1  45
# 10         Vasco da Gama  24  20   7  3  10  22  31  -9  40
# 11             CriciÃºma  24  19   6  6   7  28  29  -1  42
# 12             Juventude  22  19   5  7   7  21  25  -4  38
# 13               GrÃªmio  21  19   6  3  10  17  22  -5  36
# 14              VitÃ³ria  21  21   6  3  12  23  32  -9  33
# 15         Internacional  21  16   5  6   5  14  14   0  43
# 16            Fluminense  20  20   5  5  10  16  24  -8  33
# 17           Corinthians  20  21   4  8   9  19  28  -9  31
# 18               CuiabÃ¡  17  19   4  5  10  19  25  -6  29
# 19  AtlÃ©tico Goianiense  12  21   2  6  13  17  35 -18  19

# %%
#grafico_percent = tabela_brasileirao.groupby('Times')[['%']].mean().sort_values('%')
grafico_percent = tabela_brasileirao.groupby('Times')['%'].sum().sort_values()

# %%
! pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\ead\desktop\exercício-tarde-avaliação\.venv\lib\site-packages (3.9.1.post1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ead\desktop\exercício-tarde-avaliação\.venv\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ead\desktop\exercício-tarde-avaliação\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ead\desktop\exercício-tarde-avaliação\.venv\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ead\desktop\exercício-tarde-avaliação\.venv\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\ead\desktop\exercício-tarde-avaliação\.venv\lib\site-packages (from matplotlib) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\ead\desktop\exercício-tarde-avaliação\.venv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ead\desktop\exercício-tarde-avaliação\.venv\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ead\desktop\exercício-tarde-avaliação\.venv\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ead\desktop\exercício-tarde-avaliação\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ead\desktop\exercício-tarde-avaliação\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib as plt

# %%
grafico_percent.plot(kind='barh', figsize=(14,10), color='bluer')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[299], line 1
# ----> 1 grafico_percent.plot(kind='barh', figsize=(14,10), color='bluer')
#
# File c:\Users\ead\Desktop\exercício-tarde-avaliação\.venv\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\ead\Desktop\exercício-tarde-avaliação\.venv\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\Users\ead\Desktop\exercício-tarde-avaliação\.venv\Lib\site-packages\pandas\plotting\_matplotlib\core.py:501, in MPLPlot.generate(self)
#     499 self._compute_plot_data()
#     500 fig = self.fig
# --> 501 self._make_plot(fig)
#     502 self._add_table()
#     503 self._make_legend()
#
# File c:\Users\ead\Desktop\exercício-tarde-avaliação\.venv\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1885, in BarPlot._make_plot(self, fig)
#    1884 def _make_plot(self, fig: Figure) -> None:
# -> 1885     colors = self._get_colors()
#    1886     ncolors = len(colors)
#    1888     pos_prior = neg_prior = np.zeros(len(self.data))
#
# File c:\Users\ead\Desktop\exercício-tarde-avaliação\.venv\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1088, in MPLPlot._get_colors(self, num_colors, color_kwds)
#    1086 else:
#    1087     color = self.kwds.get(color_kwds)
# -> 1088 return get_standard_colors(
#    1089     num_colors=num_colors,
#    1090     colormap=self.colormap,
#    1091     color=color,
#    1092 )
#
# File c:\Users\ead\Desktop\exercício-tarde-avaliação\.venv\Lib\site-packages\pandas\plotting\_matplotlib\style.py:70, in get_standard_colors(num_colors, colormap, color_type, color)
#      67 if isinstance(color, dict):
#      68     return color
# ---> 70 colors = _derive_colors(
#      71     color=color,
#      72     colormap=colormap,
#      73     color_type=color_type,
#      74     num_colors=num_colors,
#      75 )
#      77 return list(_cycle_colors(colors, num_colors=num_colors))
#
# File c:\Users\ead\Desktop\exercício-tarde-avaliação\.venv\Lib\site-packages\pandas\plotting\_matplotlib\style.py:127, in _derive_colors(color, colormap, color_type, num_colors)
#     122     if colormap is not None:
#     123         warnings.warn(
#     124             "'color' and 'colormap' cannot be used simultaneously. Using 'color'",
#     125             stacklevel=find_stack_level(),
#     126         )
# --> 127     return _get_colors_from_color(color)
#     128 else:
#     129     return _get_colors_from_color_type(color_type, num_colors=num_colors)
#
# File c:\Users\ead\Desktop\exercício-tarde-avaliação\.venv\Lib\site-packages\pandas\plotting\_matplotlib\style.py:173, in _get_colors_from_color(color)
#     170     return [color]
#     172 color = cast(Collection[Color], color)
# --> 173 return list(_gen_list_of_colors_from_iterable(color))
#
# File c:\Users\ead\Desktop\exercício-tarde-avaliação\.venv\Lib\site-packages\pandas\plotting\_matplotlib\style.py:206, in _gen_list_of_colors_from_iterable(color)
#     204     yield x
#     205 else:
# --> 206     raise ValueError(f"Invalid color {x}")
#
# ValueError: Invalid color bluer

# %%
url = "https://www.tuasaude.com/imc/"
tabela_seriea = pd.read_html(url)
tabela_seriea
# Out:
# [             IMC (kg/m²)       Classificação
#  0         Menor que 18,5          Baixo peso
#  1         De 18,5 a 24,9         Peso normal
#  2           De 25 a 29,9           Sobrepeso
#  3           De 30 a 34,9    Obesidade grau I
#  4           De 35 a 39.9   Obesidade grau II
#  5  Igual ou maior que 40  Obesidade grau III]
